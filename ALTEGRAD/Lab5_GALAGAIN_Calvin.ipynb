# %%
# %%capture
"""
Deep Learning on Graphs - ALTEGRAD - Nov 2022
"""
# !pip install gensim -U
import numpy as np
import networkx as nx
from random import randint, choice
from gensim.models import Word2Vec


############## Task 1
# Simulates a random walk of length "walk_length" starting from node "node"
def random_walk(G, node, walk_length):

  ##################
  # your code here #
  walk = [node]

  for _ in range(walk_length):
    new_node = choice(list(G.neighbors(walk[-1])))
    walk.append(new_node)
  ##################
  walk = [str(node) for node in walk]
  return walk


############## Task 2
# Runs "num_walks" random walks from each node
def generate_walks(G, num_walks, walk_length):
    walks = []
    
    ##################
    # your code here #
    for node in G.nodes():
      for _ in range(num_walks):
        walks.append(random_walk(G, node, walk_length))

    permuted_walks = np.random.permutation(walks)

    ##################

    return permuted_walks.tolist()


# Simulates walks and uses the Skipgram model to learn node representations
def deepwalk(G, num_walks, walk_length, n_dim):
    print("Generating walks")
    walks = generate_walks(G, num_walks, walk_length)

    print("Training word2vec")
    model = Word2Vec(vector_size=n_dim, window=8, min_count=0, sg=1, workers=8, hs=1)
    model.build_vocab(walks)
    model.train(walks, total_examples=model.corpus_count, epochs=5)

    return model

# %%
"""
Deep Learning on Graphs - ALTEGRAD - Nov 2022
"""

import networkx as nx
import numpy as np
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# Loads the web graph
G = nx.read_weighted_edgelist('/content/drive/MyDrive/MVA/ALTEGRAD/rendu/Lab5_GALAGAIN_Calvin/code/data/web_sample.edgelist', delimiter=' ', create_using=nx.Graph())
print("Number of nodes:", G.number_of_nodes())
print("Number of edges:", G.number_of_edges())


############## Task 3
# Extracts a set of random walks from the web graph and feeds them to the Skipgram model
n_dim = 128
n_walks = 10
walk_length = 20

##################
# your code here #
model = deepwalk(G, n_walks, walk_length, n_dim)
##################

############## Task 4
# Visualizes the representations of the 100 nodes that appear most frequently in the generated walks
def visualize(model, n, dim):

    nodes = model.wv.index_to_key[:n] # your code here
    DeepWalk_embeddings = np.empty(shape=(n, dim))
    
    ##################
    # your code here #
    for idx, node in enumerate(nodes):
      DeepWalk_embeddings[idx, :] = model.wv[node]
    ##################


    my_pca = PCA(n_components=10)
    my_tsne = TSNE(n_components=2)

    vecs_pca = my_pca.fit_transform(DeepWalk_embeddings)
    vecs_tsne = my_tsne.fit_transform(vecs_pca)

    fig, ax = plt.subplots()
    ax.scatter(vecs_tsne[:,0], vecs_tsne[:,1],s=3)
    for x, y, node in zip(vecs_tsne[:,0] , vecs_tsne[:,1], nodes):     
        ax.annotate(node, xy=(x, y), size=8)
    fig.suptitle('t-SNE visualization of node embeddings',fontsize=30)
    fig.set_size_inches(20,15)
    plt.savefig('embeddings.pdf')  
    plt.show()


visualize(model, 100, n_dim)
# Out:
# Number of nodes: 33226
# Number of edges: 354529
# Generating walks
# Training word2vec
# /usr/local/lib/python3.8/dist-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %%
"""
Deep Learning on Graphs - ALTEGRAD - Nov 2022
"""

import networkx as nx
import numpy as np
from scipy.sparse.linalg import eigs
from scipy.sparse import diags, eye

from sklearn.linear_model import LogisticRegression
from sklearn.manifold import SpectralEmbedding
from sklearn.metrics import accuracy_score


# Loads the karate network
G = nx.read_weighted_edgelist('/content/drive/MyDrive/MVA/ALTEGRAD/rendu/Lab5_GALAGAIN_Calvin/code/data/karate.edgelist', delimiter=' ', nodetype=int, create_using=nx.Graph())
print("Number of nodes:", G.number_of_nodes())
print("Number of edges:", G.number_of_edges())

n = G.number_of_nodes()

# Loads the class labels
class_labels = np.loadtxt('/content/drive/MyDrive/MVA/ALTEGRAD/rendu/Lab5_GALAGAIN_Calvin/code/data/karate_labels.txt', delimiter=',', dtype=np.int32)
idx_to_class_label = dict()
for i in range(class_labels.shape[0]):
    idx_to_class_label[class_labels[i,0]] = class_labels[i,1]

y = list()
for node in G.nodes():
    y.append(idx_to_class_label[node])

y = np.array(y)


############## Task 5
# Visualizes the karate network

##################
# your code here #
nx.draw_networkx(G, node_color=y)
##################


############## Task 6
# Extracts a set of random walks from the karate network and feeds them to the Skipgram model
n_dim = 128
n_walks = 10
walk_length = 20
model = deepwalk(G, n_walks, walk_length, n_dim)# your code here

embeddings = np.zeros((n, n_dim))
for i, node in enumerate(G.nodes()):
    embeddings[i,:] = model.wv[str(node)]

idx = np.random.RandomState(seed=42).permutation(n)
idx_train = idx[:int(0.8*n)]
idx_test = idx[int(0.8*n):]

X_train = embeddings[idx_train,:]
X_test = embeddings[idx_test,:]

y_train = y[idx_train]
y_test = y[idx_test]


############## Task 7
# Trains a logistic regression classifier and use it to make predictions
##################
# your code here #
clf = LogisticRegression(solver="lbfgs")
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print(accuracy_score(y_test, y_pred))
##################


############## Task 8
# Generates spectral embeddings
##################
# your code here #
spec = SpectralEmbedding(2)
clf2 = LogisticRegression(solver="lbfgs")
clf2.fit(spec.fit_transform(X_train), y_train)
y_pred = clf2.predict(spec.fit_transform(X_test))
print(accuracy_score(y_test, y_pred))
##################
# Out:
# Number of nodes: 34
# Number of edges: 78
# Generating walks
# Training word2vec
# 1.0
# 0.5714285714285714
# /usr/local/lib/python3.8/dist-packages/sklearn/manifold/_spectral_embedding.py:260: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/manifold/_spectral_embedding.py:260: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(

# %%
"""
Deep Learning on Graphs - ALTEGRAD - Nov 2022
"""

import scipy.sparse as sp
import numpy as np
import torch
from sklearn.preprocessing import LabelEncoder

def normalize_adjacency(A):
    ############## Task 9

    ##################
    # your code here #
    n = A.shape[0]
    A += sp.identity(n)
    degs = A.dot(np.ones(n))
    degs = np.power(degs, -1./2)
    D = sp.diags(degs)
    A_normalized = D@A@D
    ##################
    return A_normalized


def load_cora():
    idx_features_labels = np.genfromtxt("/content/drive/MyDrive/MVA/ALTEGRAD/rendu/Lab5_GALAGAIN_Calvin/code/data/cora.content", dtype=np.dtype(str))
    features = sp.csr_matrix(idx_features_labels[:, 1:-1], dtype=np.float32)
    features = features.todense()
    features /= features.sum(1).reshape(-1, 1)
    
    class_labels = idx_features_labels[:, -1]
    le = LabelEncoder()
    class_labels = le.fit_transform(class_labels)

    # build graph
    idx = np.array(idx_features_labels[:, 0], dtype=np.int32)
    idx_map = {j: i for i, j in enumerate(idx)}
    edges_unordered = np.genfromtxt("/content/drive/MyDrive/MVA/ALTEGRAD/rendu/Lab5_GALAGAIN_Calvin/code/data/cora.cites", dtype=np.int32)
    edges = np.array(list(map(idx_map.get, edges_unordered.flatten())), dtype=np.int32).reshape(edges_unordered.shape)
    adj = sp.coo_matrix((np.ones(edges.shape[0]), (edges[:, 0], edges[:, 1])), shape=(class_labels.size, class_labels.size), dtype=np.float32)

    # build symmetric adjacency matrix
    adj = adj + adj.T.multiply(adj.T > adj) - adj.multiply(adj.T > adj)

    print('Dataset has {} nodes, {} edges, {} features.'.format(adj.shape[0], edges.shape[0], features.shape[1]))

    return features, adj, class_labels


def sparse_to_torch_sparse(M):
    """Converts a sparse SciPy matrix to a sparse PyTorch tensor"""
    M = M.tocoo().astype(np.float32)
    indices = torch.from_numpy(np.vstack((M.row, M.col)).astype(np.int64))
    values = torch.from_numpy(M.data)
    shape = torch.Size(M.shape)
    return torch.sparse.FloatTensor(indices, values, shape)

# %%
"""
Deep Learning on Graphs - ALTEGRAD - Nov 2022
"""

import torch
import torch.nn as nn
import torch.nn.functional as F

class GNN(nn.Module):
    """Simple GNN model"""
    def __init__(self, n_feat, n_hidden_1, n_hidden_2, n_class, dropout):
        super(GNN, self).__init__()

        self.fc1 = nn.Linear(n_feat, n_hidden_1)
        self.fc2 = nn.Linear(n_hidden_1, n_hidden_2)
        self.fc3 = nn.Linear(n_hidden_2, n_class)
        self.dropout = nn.Dropout(dropout)
        self.relu = nn.ReLU()

    def forward(self, x_in, adj):
        ############## Tasks 10 and 13
        
        ##################
        # your code here #
        h0 = self.fc1(x_in)
        z0 = self.relu(torch.mm(adj, h0))

        z0 = self.dropout(z0)

        h2 = self.fc2(z0)
        z1 = self.relu(torch.mm(adj, h2))

        x = self.fc3(z1)
        ##################


        return F.log_softmax(x, dim=1)

# %%
"""
Deep Learning on Graphs - ALTEGRAD - Nov 2022
"""

import numpy as np
import networkx as nx
import time
import torch
import torch.nn.functional as F
import torch.optim as optim
from sklearn.metrics import accuracy_score


# Initialize device
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

# Hyperparameters
epochs = 100
n_hidden_1 = 8
n_hidden_2 = 16
learning_rate = 0.01
dropout_rate = 0.1

# Loads the karate network
G = nx.read_weighted_edgelist("/content/drive/MyDrive/MVA/ALTEGRAD/rendu/Lab5_GALAGAIN_Calvin/code/data/karate.edgelist", delimiter=' ', nodetype=int, create_using=nx.Graph())
print(G.number_of_nodes())
print(G.number_of_edges())

n = G.number_of_nodes()

# Loads the class labels
class_labels = np.loadtxt("/content/drive/MyDrive/MVA/ALTEGRAD/rendu/Lab5_GALAGAIN_Calvin/code/data/karate_labels.txt", delimiter=',', dtype=np.int32)
idx_to_class_label = dict()
for i in range(class_labels.shape[0]):
    idx_to_class_label[class_labels[i,0]] = class_labels[i,1]

y = list()
for node in G.nodes():
    y.append(idx_to_class_label[node])

y = np.array(y)
n_class = 2

adj = nx.adjacency_matrix(G) # Obtains the adjacency matrix
adj = normalize_adjacency(adj) # Normalizes the adjacency matrix

############## Task 12
# Set the feature of all nodes to the same value
features = np.eye(n) # Generates node features


# Yields indices to split data into training and test sets
idx = np.random.RandomState(seed=42).permutation(n)
idx_train = idx[:int(0.8*n)]
idx_test = idx[int(0.8*n):]

# Transforms the numpy matrices/vectors to torch tensors
features = torch.FloatTensor(features).to(device)
y = torch.LongTensor(y).to(device)
adj = sparse_to_torch_sparse(adj).to(device)
idx_train = torch.LongTensor(idx_train).to(device)
idx_test = torch.LongTensor(idx_test).to(device)


# Creates the model and specifies the optimizer
model = GNN(features.shape[1], n_hidden_1, n_hidden_2, n_class, dropout_rate).to(device)
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

def train(epoch):
    t = time.time()
    model.train()
    optimizer.zero_grad()
    output = model(features, adj)
    loss_train = F.nll_loss(output[idx_train], y[idx_train])
    acc_train = accuracy_score(torch.argmax(output[idx_train], dim=1).detach().cpu().numpy(), y[idx_train].cpu().numpy())
    loss_train.backward()
    optimizer.step()

    print('Epoch: {:03d}'.format(epoch+1),
          'loss_train: {:.4f}'.format(loss_train.item()),
          'acc_train: {:.4f}'.format(acc_train),
          'time: {:.4f}s'.format(time.time() - t))


def test():
    model.eval()
    output = model(features, adj)
    loss_test = F.nll_loss(output[idx_test], y[idx_test])
    acc_test = accuracy_score(torch.argmax(output[idx_test], dim=1).detach().cpu().numpy(), y[idx_test].cpu().numpy())
    print("Test set results:",
          "loss= {:.4f}".format(loss_test.item()),
          "accuracy= {:.4f}".format(acc_test))


# Train model
t_total = time.time()
for epoch in range(epochs):
    train(epoch)
print("Optimization Finished!")
print("Total time elapsed: {:.4f}s".format(time.time() - t_total))
print()

# Testing
test()
# Out:
# 34
# 78
# Epoch: 001 loss_train: 0.6933 acc_train: 0.5556 time: 0.0043s
# Epoch: 002 loss_train: 0.6891 acc_train: 0.5556 time: 0.0036s
# Epoch: 003 loss_train: 0.6875 acc_train: 0.5556 time: 0.0035s
# Epoch: 004 loss_train: 0.6851 acc_train: 0.5556 time: 0.0049s
# Epoch: 005 loss_train: 0.6808 acc_train: 0.5556 time: 0.0047s
# Epoch: 006 loss_train: 0.6792 acc_train: 0.5556 time: 0.0032s
# Epoch: 007 loss_train: 0.6737 acc_train: 0.5556 time: 0.0037s
# Epoch: 008 loss_train: 0.6691 acc_train: 0.5556 time: 0.0038s
# Epoch: 009 loss_train: 0.6624 acc_train: 0.5556 time: 0.0035s
# Epoch: 010 loss_train: 0.6624 acc_train: 0.5926 time: 0.0039s
# Epoch: 011 loss_train: 0.6504 acc_train: 0.5926 time: 0.0047s
# Epoch: 012 loss_train: 0.6385 acc_train: 0.5926 time: 0.0047s
# Epoch: 013 loss_train: 0.6351 acc_train: 0.6296 time: 0.0037s
# Epoch: 014 loss_train: 0.6151 acc_train: 0.6667 time: 0.0037s
# Epoch: 015 loss_train: 0.5944 acc_train: 0.7037 time: 0.0046s
# Epoch: 016 loss_train: 0.5850 acc_train: 0.7037 time: 0.0037s
# Epoch: 017 loss_train: 0.5707 acc_train: 0.7407 time: 0.0040s
# Epoch: 018 loss_train: 0.5556 acc_train: 0.7778 time: 0.0043s
# Epoch: 019 loss_train: 0.5153 acc_train: 0.8889 time: 0.0036s
# Epoch: 020 loss_train: 0.5078 acc_train: 0.8889 time: 0.0040s
# Epoch: 021 loss_train: 0.4698 acc_train: 0.8889 time: 0.0041s
# Epoch: 022 loss_train: 0.4395 acc_train: 0.9630 time: 0.0039s
# Epoch: 023 loss_train: 0.4181 acc_train: 0.8889 time: 0.0050s
# Epoch: 024 loss_train: 0.3717 acc_train: 0.9259 time: 0.0047s
# Epoch: 025 loss_train: 0.3340 acc_train: 1.0000 time: 0.0067s
# Epoch: 026 loss_train: 0.3117 acc_train: 0.9630 time: 0.0055s
# Epoch: 027 loss_train: 0.2828 acc_train: 1.0000 time: 0.0041s
# Epoch: 028 loss_train: 0.2612 acc_train: 1.0000 time: 0.0037s
# Epoch: 029 loss_train: 0.2401 acc_train: 1.0000 time: 0.0039s
# Epoch: 030 loss_train: 0.1993 acc_train: 1.0000 time: 0.0049s
# Epoch: 031 loss_train: 0.1630 acc_train: 1.0000 time: 0.0038s
# Epoch: 032 loss_train: 0.1530 acc_train: 1.0000 time: 0.0038s
# Epoch: 033 loss_train: 0.1514 acc_train: 1.0000 time: 0.0035s
# Epoch: 034 loss_train: 0.1331 acc_train: 1.0000 time: 0.0032s
# Epoch: 035 loss_train: 0.1076 acc_train: 1.0000 time: 0.0042s
# Epoch: 036 loss_train: 0.0772 acc_train: 1.0000 time: 0.0035s
# Epoch: 037 loss_train: 0.0757 acc_train: 1.0000 time: 0.0047s
# Epoch: 038 loss_train: 0.0585 acc_train: 1.0000 time: 0.0037s
# Epoch: 039 loss_train: 0.0648 acc_train: 1.0000 time: 0.0076s
# Epoch: 040 loss_train: 0.0649 acc_train: 1.0000 time: 0.0054s
# Epoch: 041 loss_train: 0.0593 acc_train: 1.0000 time: 0.0040s
# Epoch: 042 loss_train: 0.0574 acc_train: 1.0000 time: 0.0047s
# Epoch: 043 loss_train: 0.0278 acc_train: 1.0000 time: 0.0039s
# Epoch: 044 loss_train: 0.0296 acc_train: 1.0000 time: 0.0050s
# Epoch: 045 loss_train: 0.0256 acc_train: 1.0000 time: 0.0053s
# Epoch: 046 loss_train: 0.0345 acc_train: 1.0000 time: 0.0043s
# Epoch: 047 loss_train: 0.0224 acc_train: 1.0000 time: 0.0052s
# Epoch: 048 loss_train: 0.0397 acc_train: 1.0000 time: 0.0044s
# Epoch: 049 loss_train: 0.0155 acc_train: 1.0000 time: 0.0035s
# Epoch: 050 loss_train: 0.0130 acc_train: 1.0000 time: 0.0051s
# Epoch: 051 loss_train: 0.0151 acc_train: 1.0000 time: 0.0040s
# Epoch: 052 loss_train: 0.0080 acc_train: 1.0000 time: 0.0050s
# Epoch: 053 loss_train: 0.0103 acc_train: 1.0000 time: 0.0042s
# Epoch: 054 loss_train: 0.0272 acc_train: 1.0000 time: 0.0049s
# Epoch: 055 loss_train: 0.0086 acc_train: 1.0000 time: 0.0048s
# Epoch: 056 loss_train: 0.0171 acc_train: 1.0000 time: 0.0051s
# Epoch: 057 loss_train: 0.0046 acc_train: 1.0000 time: 0.0051s
# Epoch: 058 loss_train: 0.0059 acc_train: 1.0000 time: 0.0048s
# Epoch: 059 loss_train: 0.0139 acc_train: 1.0000 time: 0.0046s
# Epoch: 060 loss_train: 0.0056 acc_train: 1.0000 time: 0.0040s
# Epoch: 061 loss_train: 0.0105 acc_train: 1.0000 time: 0.0041s
# Epoch: 062 loss_train: 0.0032 acc_train: 1.0000 time: 0.0049s
# Epoch: 063 loss_train: 0.0034 acc_train: 1.0000 time: 0.0041s
# Epoch: 064 loss_train: 0.0090 acc_train: 1.0000 time: 0.0041s
# Epoch: 065 loss_train: 0.0050 acc_train: 1.0000 time: 0.0050s
# Epoch: 066 loss_train: 0.0058 acc_train: 1.0000 time: 0.0041s
# Epoch: 067 loss_train: 0.0053 acc_train: 1.0000 time: 0.0049s
# Epoch: 068 loss_train: 0.0035 acc_train: 1.0000 time: 0.0049s
# Epoch: 069 loss_train: 0.0042 acc_train: 1.0000 time: 0.0043s
# Epoch: 070 loss_train: 0.0021 acc_train: 1.0000 time: 0.0036s
# Epoch: 071 loss_train: 0.0054 acc_train: 1.0000 time: 0.0048s
# Epoch: 072 loss_train: 0.0040 acc_train: 1.0000 time: 0.0051s
# Epoch: 073 loss_train: 0.0105 acc_train: 1.0000 time: 0.0035s
# Epoch: 074 loss_train: 0.0036 acc_train: 1.0000 time: 0.0040s
# Epoch: 075 loss_train: 0.0030 acc_train: 1.0000 time: 0.0041s
# Epoch: 076 loss_train: 0.0065 acc_train: 1.0000 time: 0.0042s
# Epoch: 077 loss_train: 0.0012 acc_train: 1.0000 time: 0.0041s
# Epoch: 078 loss_train: 0.0081 acc_train: 1.0000 time: 0.0079s
# Epoch: 079 loss_train: 0.0054 acc_train: 1.0000 time: 0.0054s
# Epoch: 080 loss_train: 0.0011 acc_train: 1.0000 time: 0.0037s
# Epoch: 081 loss_train: 0.0014 acc_train: 1.0000 time: 0.0041s
# Epoch: 082 loss_train: 0.0040 acc_train: 1.0000 time: 0.0038s
# Epoch: 083 loss_train: 0.0021 acc_train: 1.0000 time: 0.0033s
# Epoch: 084 loss_train: 0.0064 acc_train: 1.0000 time: 0.0041s
# Epoch: 085 loss_train: 0.0026 acc_train: 1.0000 time: 0.0048s
# Epoch: 086 loss_train: 0.0097 acc_train: 1.0000 time: 0.0041s
# Epoch: 087 loss_train: 0.0018 acc_train: 1.0000 time: 0.0039s
# Epoch: 088 loss_train: 0.0038 acc_train: 1.0000 time: 0.0048s
# Epoch: 089 loss_train: 0.0023 acc_train: 1.0000 time: 0.0052s
# Epoch: 090 loss_train: 0.0013 acc_train: 1.0000 time: 0.0063s
# Epoch: 091 loss_train: 0.0021 acc_train: 1.0000 time: 0.0042s
# Epoch: 092 loss_train: 0.0021 acc_train: 1.0000 time: 0.0059s
# Epoch: 093 loss_train: 0.0008 acc_train: 1.0000 time: 0.0060s
# Epoch: 094 loss_train: 0.0023 acc_train: 1.0000 time: 0.0064s
# Epoch: 095 loss_train: 0.0018 acc_train: 1.0000 time: 0.0054s
# Epoch: 096 loss_train: 0.0014 acc_train: 1.0000 time: 0.0033s
# Epoch: 097 loss_train: 0.0009 acc_train: 1.0000 time: 0.0037s
# Epoch: 098 loss_train: 0.0023 acc_train: 1.0000 time: 0.0047s
# Epoch: 099 loss_train: 0.0011 acc_train: 1.0000 time: 0.0035s
# Epoch: 100 loss_train: 0.0020 acc_train: 1.0000 time: 0.0038s
# Optimization Finished!
# Total time elapsed: 0.5269s
#
# Test set results: loss= 0.0001 accuracy= 1.0000

# %%
"""
Deep Learning on Graphs - ALTEGRAD - Nov 2022
"""

import numpy as np
import time
import matplotlib.pyplot as plt
import torch
import torch.nn.functional as F
import torch.optim as optim
from sklearn.metrics import accuracy_score
from sklearn.manifold import TSNE

# Initialize device
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

# Hyperparameters
epochs = 100
n_hidden_1 = 64
n_hidden_2 = 32
learning_rate = 0.01
dropout_rate = 0.5

# Read data
features, adj, class_labels = load_cora()
n = adj.shape[0] # Number of nodes
n_class = np.unique(class_labels).size # Number of classes

adj = normalize_adjacency(adj) # Normalize adjacency matrix

# Yields indices to split data into training, validation and test sets
idx = np.random.permutation(n)
idx_train = idx[:int(0.6*n)]
idx_val = idx[int(0.6*n):int(0.8*n)]
idx_test = idx[int(0.8*n):]

# Transform the numpy matrices/vectors to torch tensors
features = torch.FloatTensor(features).to(device)
y = torch.LongTensor(class_labels).to(device)
adj = sparse_to_torch_sparse(adj).to(device)
idx_train = torch.LongTensor(idx_train).to(device)
idx_val = torch.LongTensor(idx_val).to(device)
idx_test = torch.LongTensor(idx_test).to(device)


class GNN(nn.Module):
    """Simple GNN model"""
    def __init__(self, n_feat, n_hidden_1, n_hidden_2, n_class, dropout):
        super(GNN, self).__init__()

        self.fc1 = nn.Linear(n_feat, n_hidden_1)
        self.fc2 = nn.Linear(n_hidden_1, n_hidden_2)
        self.fc3 = nn.Linear(n_hidden_2, n_class)
        self.dropout = nn.Dropout(dropout)
        self.relu = nn.ReLU()

    def forward(self, x_in, adj):
        ############## Tasks 10 and 13
        
        ##################
        # your code here #
        h0 = self.fc1(x_in)
        z0 = self.relu(torch.mm(adj, h0))

        z0 = self.dropout(z0)

        h2 = self.fc2(z0)
        z1 = self.relu(torch.mm(adj, h2))

        x = self.fc3(z1)
        ##################


        return F.log_softmax(x, dim=1), h2


# Creates the model and specifies the optimizer
model = GNN(features.shape[1], n_hidden_1, n_hidden_2, n_class, dropout_rate).to(device)
optimizer = optim.Adam(model.parameters(), lr=learning_rate)


def train(epoch):
    t = time.time()
    model.train()
    optimizer.zero_grad()
    output,_ = model(features, adj)
    loss_train = F.nll_loss(output[idx_train], y[idx_train])
    acc_train = accuracy_score(torch.argmax(output[idx_train], dim=1).detach().cpu().numpy(), y[idx_train].cpu().numpy())
    loss_train.backward()
    optimizer.step()

    
    model.eval()
    output,_ = model(features, adj)

    loss_val = F.nll_loss(output[idx_val], y[idx_val])
    acc_val = accuracy_score(torch.argmax(output[idx_val], dim=1).detach().cpu().numpy(), y[idx_val].cpu().numpy())
    print('Epoch: {:03d}'.format(epoch+1),
          'loss_train: {:.4f}'.format(loss_train.item()),
          'acc_train: {:.4f}'.format(acc_train),
          'loss_val: {:.4f}'.format(loss_val.item()),
          'acc_val: {:.4f}'.format(acc_val),
          'time: {:.4f}s'.format(time.time() - t))


def test():
    model.eval()
    output, embeddings = model(features, adj)
    loss_test = F.nll_loss(output[idx_test], y[idx_test])
    acc_test = accuracy_score(torch.argmax(output[idx_test], dim=1).detach().cpu().numpy(), y[idx_test].cpu().numpy())
    
    print("Test set results:",
          "loss= {:.4f}".format(loss_test.item()),
          "accuracy= {:.4f}".format(acc_test))

    return embeddings[idx_test]


# Train model
t_total = time.time()
for epoch in range(epochs):
    train(epoch)
print("Optimization Finished!")
print("Total time elapsed: {:.4f}s".format(time.time() - t_total))
print()

# Testing
embeddings_test = test()



############## Task 13
# Transforms torch tensor to numpy matrix

##################
# your code here #
embeddings_test = embeddings_test.detach().cpu().numpy()
##################


# Projects the emerging representations to two dimensions using t-SNE

##################
# your code here #
embeddings_test_2d = TSNE(2).fit_transform(embeddings_test)
##################


labels = class_labels[idx_test.cpu()]
unique_labels = np.unique(labels)

colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k']

fig, ax = plt.subplots()
for i in range(unique_labels.size):
    idxs = [j for j in range(labels.size) if labels[j]==unique_labels[i]]
    ax.scatter(embeddings_test_2d[idxs,0], 
               embeddings_test_2d[idxs,1], 
               c=colors[i],
               label=i,
               alpha=0.7,
               s=10)

ax.legend(scatterpoints=1)
fig.suptitle('T-SNE Visualization of the nodes of the test set',fontsize=12)
fig.set_size_inches(15,9)
plt.show()
# Out:
# Dataset has 2708 nodes, 5429 edges, 1433 features.
# Epoch: 001 loss_train: 1.9259 acc_train: 0.2888 loss_val: 1.9140 acc_val: 0.3081 time: 0.0071s
# Epoch: 002 loss_train: 1.9140 acc_train: 0.2888 loss_val: 1.9004 acc_val: 0.3081 time: 0.0077s
# Epoch: 003 loss_train: 1.9018 acc_train: 0.2888 loss_val: 1.8847 acc_val: 0.3081 time: 0.0083s
# Epoch: 004 loss_train: 1.8875 acc_train: 0.2888 loss_val: 1.8667 acc_val: 0.3081 time: 0.0124s
# Epoch: 005 loss_train: 1.8714 acc_train: 0.2888 loss_val: 1.8480 acc_val: 0.3081 time: 0.0067s
# Epoch: 006 loss_train: 1.8548 acc_train: 0.2888 loss_val: 1.8299 acc_val: 0.3081 time: 0.0075s
# Epoch: 007 loss_train: 1.8386 acc_train: 0.2888 loss_val: 1.8148 acc_val: 0.3081 time: 0.0082s
# Epoch: 008 loss_train: 1.8262 acc_train: 0.2888 loss_val: 1.8040 acc_val: 0.3081 time: 0.0073s
# Epoch: 009 loss_train: 1.8139 acc_train: 0.2888 loss_val: 1.7955 acc_val: 0.3081 time: 0.0083s
# Epoch: 010 loss_train: 1.8069 acc_train: 0.2888 loss_val: 1.7844 acc_val: 0.3081 time: 0.0073s
# Epoch: 011 loss_train: 1.7978 acc_train: 0.2888 loss_val: 1.7694 acc_val: 0.3081 time: 0.0075s
# Epoch: 012 loss_train: 1.7752 acc_train: 0.2888 loss_val: 1.7516 acc_val: 0.3081 time: 0.0071s
# Epoch: 013 loss_train: 1.7588 acc_train: 0.2888 loss_val: 1.7321 acc_val: 0.3081 time: 0.0074s
# Epoch: 014 loss_train: 1.7342 acc_train: 0.2888 loss_val: 1.7104 acc_val: 0.3081 time: 0.0083s
# Epoch: 015 loss_train: 1.7129 acc_train: 0.2888 loss_val: 1.6860 acc_val: 0.3081 time: 0.0074s
# Epoch: 016 loss_train: 1.6883 acc_train: 0.2888 loss_val: 1.6574 acc_val: 0.3081 time: 0.0084s
# Epoch: 017 loss_train: 1.6579 acc_train: 0.2888 loss_val: 1.6232 acc_val: 0.3081 time: 0.0075s
# Epoch: 018 loss_train: 1.6242 acc_train: 0.2894 loss_val: 1.5854 acc_val: 0.3081 time: 0.0075s
# Epoch: 019 loss_train: 1.5902 acc_train: 0.2931 loss_val: 1.5487 acc_val: 0.3081 time: 0.0075s
# Epoch: 020 loss_train: 1.5617 acc_train: 0.2950 loss_val: 1.5145 acc_val: 0.3192 time: 0.0076s
# Epoch: 021 loss_train: 1.5183 acc_train: 0.3103 loss_val: 1.4797 acc_val: 0.3524 time: 0.0103s
# Epoch: 022 loss_train: 1.4882 acc_train: 0.3368 loss_val: 1.4459 acc_val: 0.3930 time: 0.0099s
# Epoch: 023 loss_train: 1.4592 acc_train: 0.3645 loss_val: 1.4173 acc_val: 0.4188 time: 0.0094s
# Epoch: 024 loss_train: 1.4336 acc_train: 0.4064 loss_val: 1.3904 acc_val: 0.4262 time: 0.0065s
# Epoch: 025 loss_train: 1.4025 acc_train: 0.4175 loss_val: 1.3619 acc_val: 0.4262 time: 0.0081s
# Epoch: 026 loss_train: 1.3724 acc_train: 0.4200 loss_val: 1.3332 acc_val: 0.4299 time: 0.0073s
# Epoch: 027 loss_train: 1.3415 acc_train: 0.4273 loss_val: 1.3057 acc_val: 0.4354 time: 0.0069s
# Epoch: 028 loss_train: 1.3123 acc_train: 0.4292 loss_val: 1.2778 acc_val: 0.4446 time: 0.0073s
# Epoch: 029 loss_train: 1.2783 acc_train: 0.4550 loss_val: 1.2477 acc_val: 0.4834 time: 0.0069s
# Epoch: 030 loss_train: 1.2518 acc_train: 0.4809 loss_val: 1.2168 acc_val: 0.5166 time: 0.0075s
# Epoch: 031 loss_train: 1.2132 acc_train: 0.5320 loss_val: 1.1861 acc_val: 0.5480 time: 0.0071s
# Epoch: 032 loss_train: 1.1706 acc_train: 0.5530 loss_val: 1.1541 acc_val: 0.5886 time: 0.0072s
# Epoch: 033 loss_train: 1.1507 acc_train: 0.5936 loss_val: 1.1203 acc_val: 0.6181 time: 0.0080s
# Epoch: 034 loss_train: 1.1096 acc_train: 0.6182 loss_val: 1.0850 acc_val: 0.6273 time: 0.0071s
# Epoch: 035 loss_train: 1.0734 acc_train: 0.6576 loss_val: 1.0501 acc_val: 0.6494 time: 0.0075s
# Epoch: 036 loss_train: 1.0328 acc_train: 0.6644 loss_val: 1.0161 acc_val: 0.6863 time: 0.0064s
# Epoch: 037 loss_train: 1.0057 acc_train: 0.6927 loss_val: 0.9838 acc_val: 0.7030 time: 0.0081s
# Epoch: 038 loss_train: 0.9609 acc_train: 0.7014 loss_val: 0.9523 acc_val: 0.7066 time: 0.0091s
# Epoch: 039 loss_train: 0.9234 acc_train: 0.7248 loss_val: 0.9219 acc_val: 0.7103 time: 0.0073s
# Epoch: 040 loss_train: 0.8843 acc_train: 0.7328 loss_val: 0.8930 acc_val: 0.7269 time: 0.0063s
# Epoch: 041 loss_train: 0.8526 acc_train: 0.7278 loss_val: 0.8663 acc_val: 0.7288 time: 0.0080s
# Epoch: 042 loss_train: 0.8196 acc_train: 0.7475 loss_val: 0.8411 acc_val: 0.7288 time: 0.0074s
# Epoch: 043 loss_train: 0.7948 acc_train: 0.7494 loss_val: 0.8168 acc_val: 0.7325 time: 0.0067s
# Epoch: 044 loss_train: 0.7747 acc_train: 0.7525 loss_val: 0.7930 acc_val: 0.7362 time: 0.0086s
# Epoch: 045 loss_train: 0.7392 acc_train: 0.7611 loss_val: 0.7706 acc_val: 0.7417 time: 0.0099s
# Epoch: 046 loss_train: 0.7112 acc_train: 0.7672 loss_val: 0.7492 acc_val: 0.7417 time: 0.0063s
# Epoch: 047 loss_train: 0.6843 acc_train: 0.7722 loss_val: 0.7290 acc_val: 0.7472 time: 0.0057s
# Epoch: 048 loss_train: 0.6735 acc_train: 0.7691 loss_val: 0.7099 acc_val: 0.7509 time: 0.0066s
# Epoch: 049 loss_train: 0.6481 acc_train: 0.7759 loss_val: 0.6904 acc_val: 0.7528 time: 0.0079s
# Epoch: 050 loss_train: 0.6184 acc_train: 0.7820 loss_val: 0.6721 acc_val: 0.7546 time: 0.0073s
# Epoch: 051 loss_train: 0.5915 acc_train: 0.7919 loss_val: 0.6562 acc_val: 0.7601 time: 0.0072s
# Epoch: 052 loss_train: 0.5893 acc_train: 0.7956 loss_val: 0.6401 acc_val: 0.7601 time: 0.0065s
# Epoch: 053 loss_train: 0.5570 acc_train: 0.8036 loss_val: 0.6247 acc_val: 0.7731 time: 0.0065s
# Epoch: 054 loss_train: 0.5386 acc_train: 0.8011 loss_val: 0.6084 acc_val: 0.7804 time: 0.0079s
# Epoch: 055 loss_train: 0.5147 acc_train: 0.8183 loss_val: 0.5928 acc_val: 0.7878 time: 0.0114s
# Epoch: 056 loss_train: 0.4870 acc_train: 0.8294 loss_val: 0.5808 acc_val: 0.8007 time: 0.0082s
# Epoch: 057 loss_train: 0.4802 acc_train: 0.8399 loss_val: 0.5655 acc_val: 0.8100 time: 0.0070s
# Epoch: 058 loss_train: 0.4518 acc_train: 0.8547 loss_val: 0.5548 acc_val: 0.8137 time: 0.0071s
# Epoch: 059 loss_train: 0.4485 acc_train: 0.8578 loss_val: 0.5427 acc_val: 0.8173 time: 0.0062s
# Epoch: 060 loss_train: 0.4252 acc_train: 0.8633 loss_val: 0.5309 acc_val: 0.8266 time: 0.0067s
# Epoch: 061 loss_train: 0.4024 acc_train: 0.8725 loss_val: 0.5227 acc_val: 0.8266 time: 0.0067s
# Epoch: 062 loss_train: 0.3831 acc_train: 0.8910 loss_val: 0.5146 acc_val: 0.8339 time: 0.0084s
# Epoch: 063 loss_train: 0.3894 acc_train: 0.8842 loss_val: 0.5051 acc_val: 0.8358 time: 0.0080s
# Epoch: 064 loss_train: 0.3680 acc_train: 0.8879 loss_val: 0.4978 acc_val: 0.8450 time: 0.0071s
# Epoch: 065 loss_train: 0.3507 acc_train: 0.9002 loss_val: 0.4922 acc_val: 0.8469 time: 0.0081s
# Epoch: 066 loss_train: 0.3398 acc_train: 0.8966 loss_val: 0.4863 acc_val: 0.8469 time: 0.0064s
# Epoch: 067 loss_train: 0.3365 acc_train: 0.9027 loss_val: 0.4810 acc_val: 0.8506 time: 0.0073s
# Epoch: 068 loss_train: 0.3268 acc_train: 0.8922 loss_val: 0.4775 acc_val: 0.8524 time: 0.0079s
# Epoch: 069 loss_train: 0.3048 acc_train: 0.9113 loss_val: 0.4755 acc_val: 0.8506 time: 0.0096s
# Epoch: 070 loss_train: 0.2936 acc_train: 0.9076 loss_val: 0.4727 acc_val: 0.8542 time: 0.0065s
# Epoch: 071 loss_train: 0.2829 acc_train: 0.9175 loss_val: 0.4701 acc_val: 0.8542 time: 0.0078s
# Epoch: 072 loss_train: 0.2806 acc_train: 0.9181 loss_val: 0.4683 acc_val: 0.8561 time: 0.0067s
# Epoch: 073 loss_train: 0.2648 acc_train: 0.9200 loss_val: 0.4658 acc_val: 0.8616 time: 0.0066s
# Epoch: 074 loss_train: 0.2588 acc_train: 0.9181 loss_val: 0.4644 acc_val: 0.8635 time: 0.0066s
# Epoch: 075 loss_train: 0.2544 acc_train: 0.9224 loss_val: 0.4638 acc_val: 0.8690 time: 0.0062s
# Epoch: 076 loss_train: 0.2424 acc_train: 0.9169 loss_val: 0.4610 acc_val: 0.8690 time: 0.0079s
# Epoch: 077 loss_train: 0.2433 acc_train: 0.9261 loss_val: 0.4595 acc_val: 0.8690 time: 0.0060s
# Epoch: 078 loss_train: 0.2355 acc_train: 0.9230 loss_val: 0.4608 acc_val: 0.8616 time: 0.0072s
# Epoch: 079 loss_train: 0.2361 acc_train: 0.9249 loss_val: 0.4612 acc_val: 0.8672 time: 0.0070s
# Epoch: 080 loss_train: 0.2288 acc_train: 0.9347 loss_val: 0.4581 acc_val: 0.8727 time: 0.0078s
# Epoch: 081 loss_train: 0.2166 acc_train: 0.9249 loss_val: 0.4558 acc_val: 0.8708 time: 0.0075s
# Epoch: 082 loss_train: 0.2242 acc_train: 0.9298 loss_val: 0.4566 acc_val: 0.8727 time: 0.0110s
# Epoch: 083 loss_train: 0.2118 acc_train: 0.9329 loss_val: 0.4586 acc_val: 0.8727 time: 0.0079s
# Epoch: 084 loss_train: 0.2047 acc_train: 0.9353 loss_val: 0.4608 acc_val: 0.8690 time: 0.0078s
# Epoch: 085 loss_train: 0.1930 acc_train: 0.9384 loss_val: 0.4629 acc_val: 0.8708 time: 0.0062s
# Epoch: 086 loss_train: 0.1906 acc_train: 0.9433 loss_val: 0.4652 acc_val: 0.8708 time: 0.0067s
# Epoch: 087 loss_train: 0.1848 acc_train: 0.9440 loss_val: 0.4650 acc_val: 0.8745 time: 0.0066s
# Epoch: 088 loss_train: 0.1878 acc_train: 0.9378 loss_val: 0.4660 acc_val: 0.8653 time: 0.0061s
# Epoch: 089 loss_train: 0.1830 acc_train: 0.9372 loss_val: 0.4691 acc_val: 0.8635 time: 0.0069s
# Epoch: 090 loss_train: 0.1811 acc_train: 0.9397 loss_val: 0.4705 acc_val: 0.8616 time: 0.0074s
# Epoch: 091 loss_train: 0.1785 acc_train: 0.9427 loss_val: 0.4725 acc_val: 0.8653 time: 0.0062s
# Epoch: 092 loss_train: 0.1738 acc_train: 0.9440 loss_val: 0.4739 acc_val: 0.8653 time: 0.0067s
# Epoch: 093 loss_train: 0.1663 acc_train: 0.9470 loss_val: 0.4759 acc_val: 0.8708 time: 0.0094s
# Epoch: 094 loss_train: 0.1710 acc_train: 0.9452 loss_val: 0.4783 acc_val: 0.8708 time: 0.0069s
# Epoch: 095 loss_train: 0.1709 acc_train: 0.9403 loss_val: 0.4781 acc_val: 0.8745 time: 0.0077s
# Epoch: 096 loss_train: 0.1562 acc_train: 0.9483 loss_val: 0.4779 acc_val: 0.8708 time: 0.0070s
# Epoch: 097 loss_train: 0.1609 acc_train: 0.9470 loss_val: 0.4799 acc_val: 0.8690 time: 0.0061s
# Epoch: 098 loss_train: 0.1503 acc_train: 0.9495 loss_val: 0.4823 acc_val: 0.8690 time: 0.0071s
# Epoch: 099 loss_train: 0.1514 acc_train: 0.9520 loss_val: 0.4863 acc_val: 0.8672 time: 0.0077s
# Epoch: 100 loss_train: 0.1539 acc_train: 0.9477 loss_val: 0.4898 acc_val: 0.8635 time: 0.0061s
# Optimization Finished!
# Total time elapsed: 0.8667s
#
# Test set results: loss= 0.5927 accuracy= 0.8616
# /usr/local/lib/python3.8/dist-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
